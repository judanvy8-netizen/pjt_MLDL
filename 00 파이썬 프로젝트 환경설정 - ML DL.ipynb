# %% [markdown]
# ### 프로젝트 환경 설정 --> 패키지 설치 --> 인텔리제이 터미널
#
# 1. 파이썬 버전 : 3.11.9 ok
# 2. pip install matplotlib==3.10.0
# 3. numpy==2.0.2
# 4. scikit-learn==1.6.1
# 5. tensorflow==2.18.0
# 6. keras==3.8.0
# 7. pytorch --> 파이토치는 여러분의 컴퓨터의 GPU 에 따라서 설치해야 합니다
# > CPU 버전으로 설치합니다
#   ```
#   python -m pip install torch==2.6.0 torchvision==0.21.0 torchaudio==2.6.0 --index-url https://download.pytorch.org/whl/cpu
#   ```
# > 다음 명령으로 확인합니다 python -c "import torch; print(torch.__version__)"
#   ```
#   정상이면 나오는 메세지
#   2.6.0+cpu
#   ```
# 8. transformers==4.52.4
