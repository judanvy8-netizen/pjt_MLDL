# %%
import pandas as pd

df = pd.DataFrame({
    'name': ['홍길동', '김철수', '이영희'],
    'age': [20, 25, 23],
    'score': [90, 80, 95]
})

# print(df)
df
# Out:
#   name  age  score
# 0  홍길동   20     90
# 1  김철수   25     80
# 2  이영희   23     95

# %%
df['age']
# Out:
# 0    20
# 1    25
# 2    23
# Name: age, dtype: int64

# %%
type(df['age'])
# Out:
# pandas.Series

# %%
df[['name','age']]
type(df[['name','age']])
# Out:
# pandas.DataFrame

# %%
df.age
# Out:
# 0    20
# 1    25
# 2    23
# Name: age, dtype: int64

# %%
df.loc[:, 'age']
# Out:
# 0    20
# 1    25
# 2    23
# Name: age, dtype: int64

# %%
df.loc[:, ['name','age']]
# Out:
#   name  age
# 0  홍길동   20
# 1  김철수   25
# 2  이영희   23

# %%
df.iloc[:,1]
# Out:
# 0    20
# 1    25
# 2    23
# Name: age, dtype: int64

# %%
df.iloc[:, [0,2]]
# Out:
#   name  score
# 0  홍길동     90
# 1  김철수     80
# 2  이영희     95
